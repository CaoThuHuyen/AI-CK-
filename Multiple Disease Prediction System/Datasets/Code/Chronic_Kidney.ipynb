# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, f1_score 
from imblearn.under_sampling import RandomUnderSampler
import matplotlib.pyplot as plt

# Load your imbalanced data into a Pandas DataFrame
data = pd.read_csv('D:/Multiple-Disease-Prediction-Webapp-main/Multiple-Disease-Prediction-Webapp-main/Datasets/Chronic_Kidney_disease.csv')
# Drop rows with missing values
data.dropna(inplace=True)

# Clean up column names
data.columns = data.columns.str.strip()  # Remove leading/trailing whitespaces
data.columns = data.columns.str.replace('\t', '')  # Remove '\t' characters

# Check column names after cleaning
print(data.columns)

# Define features and target variable
X = data.drop('classification', axis=1)
y = data['classification']
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
X.head()
# Out:
#     id   age    bp     sg   al   su       rbc        pc         pcc  \
# 3    3  48.0  70.0  1.005  4.0  0.0    normal  abnormal     present
# 9    9  53.0  90.0  1.020  2.0  0.0  abnormal  abnormal     present
# 11  11  63.0  70.0  1.010  3.0  0.0  abnormal  abnormal     present
# 14  14  68.0  80.0  1.010  3.0  2.0    normal  abnormal     present
# 20  20  61.0  80.0  1.015  2.0  0.0  abnormal  abnormal  notpresent
#
#             ba  ...  hemo  pcv     wc   rc  htn   dm  cad appet   pe  ane
# 3   notpresent  ...  11.2   32   6700  3.9  yes   no   no  poor  yes  yes
# 9   notpresent  ...   9.5   29  12100  3.7  yes  yes   no  poor   no  yes
# 11  notpresent  ...  10.8   32   4500  3.8  yes  yes   no  poor  yes   no
# 14     present  ...   5.6   16  11000  2.6  yes  yes  yes  poor  yes   no
# 20  notpresent  ...   7.7   24   9200  3.2  yes  yes  yes  poor  yes  yes
#
# [5 rows x 25 columns]

# %%
# Display data types and unique values for each column
for column in data.columns:
    print(f"{column}: {data[column].dtype}, Unique Values: {data[column].unique()}")
# Out:
# id: int64, Unique Values: [  3   9  11  14  20  22  27  48  58  71  74  76  84  90  91  92  93 127
#  128 130 133 144 147 153 157 159 171 176 181 189 190 196 198 210 212 213
#  225 226 229 242 246 248 249 250 251 252 253 254 255 256 257 258 259 260
#  261 262 263 264 265 266 267 269 270 271 272 275 277 278 279 281 282 284
#  285 286 289 291 292 296 298 299 301 304 305 306 307 308 310 311 313 314
#  317 318 320 321 323 325 326 327 329 331 333 335 337 338 339 340 341 342
#  343 344 345 347 348 351 352 353 354 355 356 357 358 359 360 361 362 364
#  366 367 368 369 370 371 372 373 374 375 376 377 379 380 382 383 384 385
#  386 387 388 389 390 391 392 393 394 395 396 397 398 399]
# age: float64, Unique Values: [48. 53. 63. 68. 61. 69. 73. 46. 56. 59. 71. 52. 50. 70. 60. 55. 62. 83.
#  21. 45. 64.  6. 49. 40. 23. 57. 51. 34. 38. 42. 35. 30. 25. 24. 20. 33.
#  66. 47. 41. 44. 43. 39. 58. 65. 32. 37. 22. 29. 74. 75. 28. 72. 79. 80.
#  15. 36. 12. 17.]
# bp: float64, Unique Values: [ 70.  90.  80.  60. 100.  50. 110.]
# sg: float64, Unique Values: [1.005 1.02  1.01  1.015 1.025]
# al: float64, Unique Values: [4. 2. 3. 0. 1.]
# su: float64, Unique Values: [0. 2. 4. 1. 3. 5.]
# rbc: object, Unique Values: ['normal' 'abnormal']
# pc: object, Unique Values: ['abnormal' 'normal']
# pcc: object, Unique Values: ['present' 'notpresent']
# ba: object, Unique Values: ['notpresent' 'present']
# bgr: float64, Unique Values: [117.  70. 380. 157. 173.  95. 264. 253. 163. 129. 133.  76. 280. 210.
#  219. 295. 118. 224. 128. 105. 288. 273. 122. 303. 102. 107. 239.  94.
#  252. 255. 214. 490. 241. 106. 424. 176. 140.  82. 119.  99. 121. 131.
#   91.  98. 104. 132.  97. 111.  96. 139. 125. 123. 112. 130. 100.  81.
#   93. 124.  89. 127. 137. 120. 109.  80. 134.  92.  88. 108.  83.  86.
#   87.  79.  74.  78. 113.  75.  85. 114.]
# bu: float64, Unique Values: [ 56. 107.  60.  90. 148. 163.  87.  32. 142.  92. 139. 186.  35.  26.
#   82. 125. 166. 208.  53.  36. 235.  42.  40.  52.  58.  67. 158. 132.
#  150.  73.  95.  54. 191.  96. 215.  55. 309.  10.  49.  17.  38.  27.
#   20.  31.  18.  46.  24.  33.  19.  34.  25.  15.  22.  44.  23.  50.
#   37.  48.  30.  28.  29.  39.  45.  47.  16.  41.]
# sc: float64, Unique Values: [ 3.8  7.2  2.7  4.1  3.9  7.7  0.9  4.6  3.3  6.7  8.5 15.   3.2  1.7
#   3.6  5.6  5.3  9.2  2.3 14.2  1.3  2.6  2.2  4.3  1.  11.8 12.8 11.9
#  12.   6.3 15.2 13.3  1.2  0.6  0.8  0.5  0.7  1.1  0.4]
# sod: float64, Unique Values: [111. 114. 131. 130. 135. 136. 125. 138. 141. 132. 143. 133. 140. 134.
#  122. 115. 137. 120. 124. 150. 147. 144. 146. 139. 142. 145.]
# pot: float64, Unique Values: [ 2.5  3.7  4.2  6.4  5.2  3.8  4.   5.8  4.8  5.5  7.6  3.5  4.4  2.9
#   4.9 47.   3.   3.4  4.7  5.7  5.4  3.2  5.6  4.6  3.9  4.5  6.5  5.
#   3.6  4.1  4.3  3.3]
# hemo: float64, Unique Values: [11.2  9.5 10.8  5.6  7.7  9.8 12.5 10.  10.5  9.1 10.3  7.1 13.  16.1
#  10.4  9.2 11.4  8.1  8.2 12.  11.1  7.9  8.3 12.6  8.7  9.9  7.3 10.9
#  11.5  9.6  9.4  8.6  3.1 15.  17.  15.9 15.4 13.6 14.5 14.  13.9 14.1
#  15.5 16.2 14.4 14.2 13.2 14.3 13.8 14.8 16.5 15.7 16.3 14.6 16.9 16.
#  14.7 16.6 14.9 16.7 16.8 13.5 15.1 13.1 17.1 15.2 13.7 17.3 15.6 17.4
#  15.8 13.4 17.7 17.8 13.3 17.5 17.2 17.6 16.4 15.3]
# pcv: object, Unique Values: ['32' '29' '16' '24' '37' '33' '28' '36' '22' '40' '52' '30' '35' '23'
#  '25' '39' '26' '20' '31' '34' '9' '48' '46' '42' '49' '41' '44' '45' '43'
#  '50' '51' '47' '53' '54']
# wc: object, Unique Values: ['6700' '12100' '4500' '11000' '9200' '6900' '9600' '18900' '7200' '14600'
#  '6400' '\t6200' '3800' '9800' '12500' '5600' '7000' '15200' '5000'
#  '16300' '\t8400' '10500' '7900' '10900' '12800' '12400' '19100' '7500'
#  '16700' '26400' '8800' '7400' '12000' '15700' '11500' '10200' '5400'
#  '10400' '9100' '6200' '8300' '10700' '8400' '4300' '9400' '8600' '6800'
#  '9500' '9000' '4700' '6300' '5800' '5500' '5300' '7100' '8200' '8100'
#  '7800' '7300' '7700' '9900' '5200' '6000' '10300' '9300' '6500' '8000'
#  '9700' '5100' '5700' '6600']
# rc: object, Unique Values: ['3.9' '3.7' '3.8' '2.6' '3.2' '3.4' '4.1' '3.5' '4.3' '4' '2.1' '4.2'
#  '5.6' '3.6' '2.9' '2.7' '8' '3' '3.1' '4.8' '4.5' '3.3' '2.5' '5' '4.7'
#  '6.2' '5.2' '6.3' '5.1' '5.8' '5.5' '5.3' '4.9' '5.4' '4.6' '6.4' '6'
#  '5.9' '5.7' '6.5' '6.1']
# htn: object, Unique Values: ['yes' 'no']
# dm: object, Unique Values: ['no' 'yes']
# cad: object, Unique Values: ['no' 'yes']
# appet: object, Unique Values: ['poor' 'good']
# pe: object, Unique Values: ['yes' 'no']
# ane: object, Unique Values: ['yes' 'no']
# classification: object, Unique Values: ['ckd' 'notckd']

# %%
y.head()
# Out:
# 3     ckd
# 9     ckd
# 11    ckd
# 14    ckd
# 20    ckd
# Name: classification, dtype: object

# %%
data.head()
# Out:
#     id   age    bp     sg   al   su       rbc        pc         pcc  \
# 3    3  48.0  70.0  1.005  4.0  0.0    normal  abnormal     present
# 9    9  53.0  90.0  1.020  2.0  0.0  abnormal  abnormal     present
# 11  11  63.0  70.0  1.010  3.0  0.0  abnormal  abnormal     present
# 14  14  68.0  80.0  1.010  3.0  2.0    normal  abnormal     present
# 20  20  61.0  80.0  1.015  2.0  0.0  abnormal  abnormal  notpresent
#
#             ba  ...  pcv     wc   rc  htn   dm  cad appet   pe  ane  \
# 3   notpresent  ...   32   6700  3.9  yes   no   no  poor  yes  yes
# 9   notpresent  ...   29  12100  3.7  yes  yes   no  poor   no  yes
# 11  notpresent  ...   32   4500  3.8  yes  yes   no  poor  yes   no
# 14     present  ...   16  11000  2.6  yes  yes  yes  poor  yes   no
# 20  notpresent  ...   24   9200  3.2  yes  yes  yes  poor  yes  yes
#
#    classification
# 3             ckd
# 9             ckd
# 11            ckd
# 14            ckd
# 20            ckd
#
# [5 rows x 26 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 158 entries, 3 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              158 non-null    int64
#  1   age             158 non-null    float64
#  2   bp              158 non-null    float64
#  3   sg              158 non-null    float64
#  4   al              158 non-null    float64
#  5   su              158 non-null    float64
#  6   rbc             158 non-null    object
#  7   pc              158 non-null    object
#  8   pcc             158 non-null    object
#  9   ba              158 non-null    object
#  10  bgr             158 non-null    float64
#  11  bu              158 non-null    float64
#  12  sc              158 non-null    float64
#  13  sod             158 non-null    float64
#  14  pot             158 non-null    float64
#  15  hemo            158 non-null    float64
#  16  pcv             158 non-null    object
#  17  wc              158 non-null    object
#  18  rc              158 non-null    object
#  19  htn             158 non-null    object
#  20  dm              158 non-null    object
#  21  cad             158 non-null    object
#  22  appet           158 non-null    object
#  23  pe              158 non-null    object
#  24  ane             158 non-null    object
#  25  classification  158 non-null    object
# dtypes: float64(11), int64(1), object(14)
# memory usage: 33.3+ KB

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, f1_score
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
import joblib

# Assuming 'data' is your DataFrame
label_encoder = LabelEncoder()

# List of binary categorical columns
binary_categorical_columns = ['rbc', 'pc', 'pcc', 'ba', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane', 'classification']

# Apply label encoding to each binary categorical column
for column in binary_categorical_columns:
    data[column] = label_encoder.fit_transform(data[column])

# Define features and target variable
X = data.drop(['classification','id'], axis=1)
y = data['classification']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
print(X_train)

# Define the SVM model
svm_classifier = SVC(probability=True, random_state=42)

# Train the SVM model
svm_classifier.fit(X_train, y_train)

# Make predictions on the test set
y_pred_svm = svm_classifier.predict(X_test)

# Evaluate the model
accuracy_svm = accuracy_score(y_test, y_pred_svm)
f1_svm = f1_score(y_test, y_pred_svm)

# Print evaluation metrics
print("\nSVM Test Results:")
print(f"Accuracy: {accuracy_svm}")
print(f"F1-Score: {f1_svm}")

# Save the model to a .sav file
joblib.dump(svm_classifier, 'chronic_disease_model.sav')
# Out:
#       age    bp     sg   al   su  rbc  pc  pcc  ba    bgr  ...  hemo  pcv  \
# 383  80.0  80.0  1.025  0.0  0.0    1   1    0   0  119.0  ...  13.9   49
# 76   48.0  80.0  1.005  4.0  0.0    0   0    0   1  133.0  ...  10.3   36
# 299  73.0  60.0  1.020  0.0  0.0    1   1    0   0  127.0  ...  15.1   52
# 279  24.0  70.0  1.025  0.0  0.0    1   1    0   0  140.0  ...  16.3   48
# 361  29.0  80.0  1.020  0.0  0.0    1   1    0   0   70.0  ...  13.7   54
# ..    ...   ...    ...  ...  ...  ...  ..  ...  ..    ...  ...   ...  ...
# 284  33.0  80.0  1.025  0.0  0.0    1   1    0   0  100.0  ...  16.9   52
# 341  63.0  70.0  1.025  0.0  0.0    1   1    0   0  130.0  ...  13.4   41
# 91   56.0  70.0  1.015  4.0  1.0    0   1    0   0  210.0  ...  16.1   52
# 320  57.0  60.0  1.020  0.0  0.0    1   1    0   0  105.0  ...  15.7   44
# 337  44.0  70.0  1.025  0.0  0.0    1   1    0   0   92.0  ...  14.0   52
#
#          wc   rc  htn dm cad appet  pe  ane
# 383    5100    5    0  0   0     0   0    0
# 76   \t6200    4    0  1   0     0   1    0
# 299   11000  4.7    0  0   0     0   0    0
# 279    5800  5.6    0  0   0     0   0    0
# 361    5400  5.8    0  0   0     0   0    0
# ..      ...  ...  ... ..  ..   ...  ..  ...
# 284    6700    6    0  0   0     0   0    0
# 341    7300  4.7    0  0   0     0   0    0
# 91    12500  5.6    0  0   0     0   0    0
# 320   10400  6.2    0  0   0     0   0    0
# 337    7500  6.2    0  0   0     0   0    0
#
# [110 rows x 24 columns]
#
# SVM Test Results:
# Accuracy: 0.8125
# F1-Score: 0.8860759493670886
# ['chronic_disease_model.sav']
